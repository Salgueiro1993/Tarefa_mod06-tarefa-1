# %% [markdown]
# # Módulo 6 tarefa 1
#
# #### 1) A base 'sinasc_RO_2019.csv' contém dados do sistema de nascidos vivos do DataSUS, cujo dicionário de dados está no arquivo 'Estrutura_SINASC_para_CD.pdf'. Carregue esses arquivos.

# %%
import seaborn as sns
# %matplotlib inline
import pandas as pd
import requests
import numpy as np
import matplotlib.pyplot as plt
sinasc = pd.read_csv('SINASC_RO_2019.csv')
print(sinasc)
# Out:
#        ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0           1  2679477.0      110001        1        19        5.0
# 1           1  2679477.0      110001        1        29        2.0
# 2           1  2679477.0      110001        1        37        9.0
# 3           1  2516500.0      110001        1        30        5.0
# 4           1  2516500.0      110001        1        30        2.0
# ...       ...        ...         ...      ...       ...        ...
# 27023       1  2604388.0      510340        1        32        2.0
# 27024       1  2752654.0      510675        1        19        1.0
# 27025       1  9659366.0      510787        1        24        2.0
# 27026       1  9659366.0      510787        1        21        2.0
# 27027       1  2795655.0      510792        1        18        5.0
#
#                 ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0          8 a 11 anos         NaN         0.0         0.0  ...           5
# ...

# %% [markdown]
# ####  2) Monte um gráficos de barras com as variáveis APGAR1, APGAR5, SEXO, GESTACAO, ESTCIVMAE.

# %%
df5 = sinasc[['APGAR1', 'APGAR5', 'SEXO', 'GESTACAO', 'ESTCIVMAE','CONSULTAS']]
import matplotlib.pyplot as plt
import pandas as pd
df5.head(5)
# Out:
#    APGAR1  APGAR5       SEXO         GESTACAO  ESTCIVMAE  CONSULTAS
# 0     9.0    10.0  Masculino  37 a 41 semanas        5.0          4
# 1     8.0     9.0   Feminino  37 a 41 semanas        2.0          4
# 2     8.0    10.0   Feminino  37 a 41 semanas        9.0          4
# 3     9.0    10.0   Feminino  37 a 41 semanas        5.0          3
# 4     8.0    10.0   Feminino  37 a 41 semanas        2.0          4

# %%
variavel_plot = ['APGAR1', 'APGAR5', 'SEXO', 'GESTACAO', 'ESTCIVMAE']

contagem_valores = df5[variavel_plot].value_counts()

plt.figure(figsize=(8, 6))
contagem_valores.plot(kind="bar")
plt.xlabel(variavel_plot)
plt.ylabel("Quantidade")
plt.title(f"Gráfico de Barras para {variavel_plot}")
plt.xticks(rotation=0)

plt.show()

# %% [markdown]
# #### 3) Monte um gráfico de barras mostrando o APGAR5 médio por CONSULTAS

# %%
media_apgar_por_consulta = df5.groupby('GESTACAO')['APGAR5'].mean()

plt.figure(figsize=(10, 6))
sns.barplot(x=media_apgar_por_consulta.index, y=media_apgar_por_consulta.values)
plt.xlabel("Consulta")
plt.ylabel("Média de APGAR5")
plt.title("Média de APGAR5 por Consulta")
plt.xticks(rotation=45)  

plt.show()

# %% [markdown]
# ####  4) Monte um painel com 4 gráficos mostrando as frequencias de SEXO, GESTACAO, ESTCIVMAE e CONSULTAS

# %%
plt.figure(figsize=(12, 10))
num_rows = 2
num_cols = 2

plt.subplot(num_rows, num_cols, 1)
sns.countplot(data=df5, x='SEXO')
plt.title("Frequência de SEXO")

plt.subplot(num_rows, num_cols, 2)
sns.countplot(data=df5, x='GESTACAO')
plt.title("Frequência de GESTACAO")

plt.subplot(num_rows, num_cols, 3)
sns.countplot(data=df5, x='ESTCIVMAE')
plt.title("Frequência de ESTCIVMAE")
plt.xticks(rotation=45)  

plt.subplot(num_rows, num_cols, 4)
sns.countplot(data=df5, x='CONSULTAS')
plt.title("Frequência de CONSULTAS")

plt.tight_layout()

plt.show()
